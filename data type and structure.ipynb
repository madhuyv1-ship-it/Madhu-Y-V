# %%
# Working with different data types

# 1. Structured Data (table-like)
soil_data = {
    'plot': ['A', 'B', 'C'],
    'pH': [6.5, 7.0, 5.8],
    'nitrogen': [80, 60, 90]
}
print("Structured Data:", soil_data)

# 2. Time Series Data
import datetime
weather_series = [
    ('2024-01-01', 25, 0),
    ('2024-01-02', 27, 5),
    ('2024-01-03', 24, 12),
]
print("\nTime Series (date, temp, rain):")
for day in weather_series:
    print(f"  {day}")

# 3. Unstructured Data Reference
print("\nImage data: stored as 3D arrays (height × width × colors)")
print("Example shape: (224, 224, 3) for a 224×224 RGB image")
# Out:
# Structured Data: {'plot': ['A', 'B', 'C'], 'pH': [6.5, 7.0, 5.8], 'nitrogen': [80, 60, 90]}
#
# Time Series (date, temp, rain):
#   ('2024-01-01', 25, 0)
#   ('2024-01-02', 27, 5)
#   ('2024-01-03', 24, 12)
#
# Image data: stored as 3D arrays (height × width × colors)
# Example shape: (224, 224, 3) for a 224×224 RGB image
